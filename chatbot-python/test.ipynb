# %%
import pandas as pd
import pprint
import json

# %%
excel = pd.read_excel("Scehdule_Ending Dec_2022_for_chatbot.xlsx")
excel
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3                     28th Nov  \
# 0         NaN        NaN        NaN        NaN                       Monday
# 1         NaN        NaN        NaN        NaN          2022-11-28 00:00:00
# 2         NaN        NaN        NaN        NaN                           AM
# 3         NaN        NaN        NaN        NaN                Final Project
# 4          C6        ???        NaN        W12  Waseesm Career Talks 11--12
# ..        ...        ...        ...        ...                          ...
# 85        NaN       Tolu  Associate        NaN                          NaN
# 86        NaN        NaN        NaN        NaN                          NaN
# 87        NaN        NaN        NaN        NaN                          NaN
# 88         C8    Ignacio      Coach        NaN    Bank Holiday and Holidays
# 89         C8    Rhainna   Asociate        NaN                          NaN
#
# ...

# %%
pprint.pprint(excel.to_json())
# Out:
# ('{"Unnamed: '
#  '0":{"0":null,"1":null,"2":null,"3":null,"4":"C6","5":"C6","6":null,"7":null,"8":null,"9":"C7","10":"C7","11":null,"12":null,"13":null,"14":"C8","15":"C8","16":null,"17":null,"18":null,"19":null,"20":null,"21":null,"22":null,"23":"C6","24":"C6","25":null,"26":null,"27":null,"28":"C7","29":"C7","30":null,"31":null,"32":null,"33":"C8","34":"C8","35":null,"36":null,"37":null,"38":null,"39":null,"40":null,"41":null,"42":"C6","43":"C6","44":null,"45":null,"46":null,"47":"C7","48":"C7","49":null,"50":null,"51":null,"52":"C8","53":"C8","54":null,"55":null,"56":null,"57":null,"58":null,"59":null,"60":null,"61":null,"62":null,"63":null,"64":null,"65":null,"66":"C7","67":"C7","68":null,"69":null,"70":null,"71":"C8","72":"C8","73":null,"74":null,"75":null,"76":null,"77":null,"78":null,"79":null,"80":null,"81":null,"82":null,"83":null,"84":null,"85":null,"86":null,"87":null,"88":"C8","89":"C8"},"Unnamed: '
# ...

# %%
import re
pattern = r"[0-9].*\": null,"
name = re.sub(r'"[0-9]+":null,','', excel.to_json(), count=0)
#name = re.sub(r'"[0-9]+":null','', name, count=0)
with open('data.json', 'w', encoding='utf-8') as f:
    f.write(name)

# %%
with open('readme.txt', 'w') as f:
    f.write('Create a new text file!')

# %%
#excel.to_json()
pprint.pprint(re.sub(r'"[0-9]+":null,','', excel.to_json(), count=0))
# Out:
# ('{"Unnamed: '
#  '0":{"4":"C6","5":"C6","9":"C7","10":"C7","14":"C8","15":"C8","23":"C6","24":"C6","28":"C7","29":"C7","33":"C8","34":"C8","42":"C6","43":"C6","47":"C7","48":"C7","52":"C8","53":"C8","66":"C7","67":"C7","71":"C8","72":"C8","88":"C8","89":"C8"},"Unnamed: '
#  '1":{"4":"???","5":"Nathan","9":"Miguel","10":"Tolu","14":"Ignacio","15":"Rhainna","23":"???","24":"Nathan","28":"Miguel","29":"Tolu","33":"Ignacio","34":"Rhainna","42":"???","43":"Nathan","47":"Miguel","48":"Tolu","52":"Ignacio","53":"Rhainna","61":"???","62":"Nathan","66":"Miguel","67":"Tolu","71":"Ignacio","72":"Rhainna","80":"???","81":"Nathan","84":"Miguel","85":"Tolu","88":"Ignacio","89":"Rhainna"},"Unnamed: '
# ...

# %%
# Opening JSON file
with open('data.json') as json_file:
    data = json.load(json_file)

# %%
for i in data:
    #print(i)
    for j in data[i]:
        #print(data[i][j])
        if j == str(0):
            print(f"{data[i][j]} {data[i][str(int(j)+1)]} {data[i][str(int(j)+2)]} {data[i][str(int(j)+3)]}")
# Out:
# Monday 1669593600000 AM Final Project
# Tuesday 1669680000000 AM Final Project
# Wednesday 1669766400000 AM Academy + (1)
# Thursday 1669852800000 AM Academy + (1)
# Friday 1669939200000 AM Academy + (1)
# Action Needed Blocked time for prep and marking Delivery Admin

# %%
df = pd.read_excel("Schedule_Cleaned.xlsm")

# %%
df.head()
# Out:
#         Date        Day Coach/Associate Name Week Cohort           Task  \
# 0 2022-11-28     Monday           Coach  NaN  W12     C6  Final Project
# 1 2022-11-29    Tuesday           Coach  NaN  W12     C6  Final Project
# 2 2022-11-30  Wednesday           Coach  NaN  W12     C6  Academy + (1)
# 3 2022-12-01   Thursday           Coach  NaN  W12     C6  Academy + (1)
# 4 2022-12-02     Friday           Coach  NaN  W12     C6  Academy + (1)
#
#                           AM   PM  EOD
# 0  Waseem Career Talks 11-12  NaN  NaN
# 1                        NaN  NaN  NaN
# 2                        NaN  NaN  NaN
# 3                        NaN  NaN  NaN
# 4                        NaN  NaN  NaN

# %%
with open('data.json') as json_file:
    data = json.load(json_file)
