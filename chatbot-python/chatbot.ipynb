# %%
import json
import string
import random
import nltk
import datetime

nltk.download("omw-1.4")
import numpy as num
from nltk.stem import WordNetLemmatizer  # It has the ability to lemmatize.
import tensorflow as tensorF  # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import (
    Sequential,
)  # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")  # required package for tokenization
nltk.download("wordnet")  # word database
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\OlatoyosiOlamideBaba\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\OlatoyosiOlamideBaba\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\OlatoyosiOlamideBaba\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = {
    "intents": [
        {
            "tag": "age",
            "patterns": ["how old are you?"],
            "responses": ["I am 2 years old and my birthday was yesterday"],
        },
        {
            "tag": "greeting",
            "patterns": ["Hi", "Hello", "Hey"],
            "responses": ["Hi there", "Hello", "Hi :)"],
        },
        {
            "tag": "goodbye",
            "patterns": ["bye", "later"],
            "responses": ["Bye", "take care"],
        },
        {
            "tag": "name",
            "patterns": ["what's your name?", "who are you?"],
            "responses": [
                "I have no name yet," "You can give me one, and I will appreciate it"
            ],
        },
        {
            "tag": "coach",
            "patterns": ["Who is our data coach?", "Who is our Associate coach"],
            "responses": ["Data Coach, Associate coach"]
        },
        {
            "tag": "task",
            "patterns": ["What is my task?", "show me a task"],
            "responses": ["Data Coach, Associate coach"]
        },
        {
            "tag": "tomorrow",
            "patterns": ["What is my task tomorrow?", "show me a task next day", "What are we covering in class tomorrow?","tomorrow",],
            "responses": ["Data Coach, Associate coach"]
        },
         {
            "tag": "schedule",
            "patterns": ["What is my task tomorrow?", "show me a task next day", "What are we covering in class tomorrow?"],
            "responses": ["Data Coach, Associate coach"]
        },
        {
            "tag": "monday",
            "patterns": ["what am i doing on monday?","What is on monday","Tasks I need to complete on monday","Tasks for monday","Schedule for monday","Upcoming monday tasks"],
            "responses": ["Data Coach, Associate coach"]
        },
        
    ]
}

# %%
lm = WordNetLemmatizer()  # for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)  # tokenize the patterns
        newWords.extend(ournewTkns)  # extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])

    if (
        intent["tag"] not in ourClasses
    ):  # add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [
    lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation
]  # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))  # sorting words
ourClasses = sorted(set(ourClasses))  # sorting classes

trainingData = []  # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(
    trainingData, dtype=object
)  # coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))  # first trainig phase
y = num.array(list(trainingData[:, 1]))  # second training phase

iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation="softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss="categorical_crossentropy", optimizer=md, metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 128)               5504
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 9)                 585
#
# =================================================================
# Total params: 14,345
# Trainable params: 14,345
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 0s 334ms/step - loss: 2.1972 - accuracy: 0.3200
# Epoch 2/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0813 - accuracy: 0.2000
# Epoch 3/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9644 - accuracy: 0.2800
# Epoch 4/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8122 - accuracy: 0.4000
# Epoch 5/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7395 - accuracy: 0.3200
# Epoch 6/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4410 - accuracy: 0.4000
# Epoch 7/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4530 - accuracy: 0.4800
# Epoch 8/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3463 - accuracy: 0.5600
# Epoch 9/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2159 - accuracy: 0.7200
# Epoch 10/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1677 - accuracy: 0.6000
# Epoch 11/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0729 - accuracy: 0.6400
# Epoch 12/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7708 - accuracy: 0.8000
# Epoch 13/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8638 - accuracy: 0.6400
# Epoch 14/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8261 - accuracy: 0.6400
# Epoch 15/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7575 - accuracy: 0.6400
# Epoch 16/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8429 - accuracy: 0.6400
# Epoch 17/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5157 - accuracy: 0.8000
# Epoch 18/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5933 - accuracy: 0.7600
# Epoch 19/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5134 - accuracy: 0.8000
# Epoch 20/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5490 - accuracy: 0.8000
# Epoch 21/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4838 - accuracy: 0.8400
# Epoch 22/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.8800
# Epoch 23/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3377 - accuracy: 0.8000
# Epoch 24/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3337 - accuracy: 0.8800
# Epoch 25/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3122 - accuracy: 0.9600
# Epoch 26/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2873 - accuracy: 0.8800
# Epoch 27/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6301 - accuracy: 0.7600
# Epoch 28/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.9600
# Epoch 29/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3804 - accuracy: 0.8400
# Epoch 30/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3249 - accuracy: 0.8800
# Epoch 31/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2232 - accuracy: 0.9200
# Epoch 32/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3485 - accuracy: 0.8800
# Epoch 33/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3888 - accuracy: 0.8400
# Epoch 34/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3554 - accuracy: 0.8400
# Epoch 35/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2456 - accuracy: 0.8800
# Epoch 36/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3505 - accuracy: 0.8800
# Epoch 37/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3112 - accuracy: 0.9200
# Epoch 38/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3364 - accuracy: 0.8000
# Epoch 39/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2533 - accuracy: 0.8400
# Epoch 40/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.8800
# Epoch 41/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1476 - accuracy: 0.9600
# Epoch 42/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4315 - accuracy: 0.8800
# Epoch 43/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9200
# Epoch 44/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3266 - accuracy: 0.8400
# Epoch 45/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2488 - accuracy: 0.8400
# Epoch 46/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1754 - accuracy: 0.9200
# Epoch 47/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1886 - accuracy: 0.9600
# Epoch 48/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1914 - accuracy: 0.9200
# Epoch 49/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 0.8400
# Epoch 50/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3814 - accuracy: 0.7600
# Epoch 51/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1807 - accuracy: 0.8800
# Epoch 52/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2016 - accuracy: 0.9200
# Epoch 53/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2128 - accuracy: 0.9200
# Epoch 54/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2480 - accuracy: 0.8800
# Epoch 55/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.9200
# Epoch 56/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.9600
# Epoch 57/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2564 - accuracy: 0.8400
# Epoch 58/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2438 - accuracy: 0.8000
# Epoch 59/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2924 - accuracy: 0.7600
# Epoch 60/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2744 - accuracy: 0.8800
# Epoch 61/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2888 - accuracy: 0.9200
# Epoch 62/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1719 - accuracy: 0.9200
# Epoch 63/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2535 - accuracy: 0.8400
# Epoch 64/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2871 - accuracy: 0.8400
# Epoch 65/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2459 - accuracy: 0.8800
# Epoch 66/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2254 - accuracy: 0.8400
# Epoch 67/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1310 - accuracy: 0.9200
# Epoch 68/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2718 - accuracy: 0.8800
# Epoch 69/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1670 - accuracy: 0.8800
# Epoch 70/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2002 - accuracy: 0.8800
# Epoch 71/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2053 - accuracy: 0.9200
# Epoch 72/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1987 - accuracy: 0.9200
# Epoch 73/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1535 - accuracy: 0.9200
# Epoch 74/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2474 - accuracy: 0.8800
# Epoch 75/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2211 - accuracy: 0.8800
# Epoch 76/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2337 - accuracy: 0.8400
# Epoch 77/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1529 - accuracy: 0.9200
# Epoch 78/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2305 - accuracy: 0.8400
# Epoch 79/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.8400
# Epoch 80/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2017 - accuracy: 0.8800
# Epoch 81/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1813 - accuracy: 0.8800
# Epoch 82/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1861 - accuracy: 0.8800
# Epoch 83/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2664 - accuracy: 0.8400
# Epoch 84/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2137 - accuracy: 0.9200
# Epoch 85/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1908 - accuracy: 0.8800
# Epoch 86/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2053 - accuracy: 0.8400
# Epoch 87/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2055 - accuracy: 0.8000
# Epoch 88/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1713 - accuracy: 0.8800
# Epoch 89/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2439 - accuracy: 0.8400
# Epoch 90/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1798 - accuracy: 0.8400
# Epoch 91/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2026 - accuracy: 0.8400
# Epoch 92/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1731 - accuracy: 0.8400
# Epoch 93/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2087 - accuracy: 0.8800
# Epoch 94/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2014 - accuracy: 0.9200
# Epoch 95/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1608 - accuracy: 0.9200
# Epoch 96/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2015 - accuracy: 0.8000
# Epoch 97/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1780 - accuracy: 0.8800
# Epoch 98/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2578 - accuracy: 0.8400
# Epoch 99/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1963 - accuracy: 0.8800
# Epoch 100/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1853 - accuracy: 0.9200
# Epoch 101/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1965 - accuracy: 0.9200
# Epoch 102/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2225 - accuracy: 0.8400
# Epoch 103/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.8800
# Epoch 104/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1713 - accuracy: 0.8800
# Epoch 105/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1886 - accuracy: 0.8400
# Epoch 106/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2578 - accuracy: 0.7600
# Epoch 107/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1766 - accuracy: 0.9200
# Epoch 108/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2140 - accuracy: 0.8400
# Epoch 109/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2181 - accuracy: 0.8800
# Epoch 110/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2010 - accuracy: 0.8400
# Epoch 111/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1891 - accuracy: 0.8400
# Epoch 112/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1567 - accuracy: 0.9200
# Epoch 113/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1846 - accuracy: 0.8800
# Epoch 114/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1968 - accuracy: 0.8400
# Epoch 115/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1557 - accuracy: 0.9600
# Epoch 116/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1894 - accuracy: 0.8400
# Epoch 117/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.8400
# Epoch 118/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1735 - accuracy: 0.9200
# Epoch 119/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1870 - accuracy: 0.8800
# Epoch 120/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2291 - accuracy: 0.8400
# Epoch 121/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1610 - accuracy: 0.8800
# Epoch 122/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1706 - accuracy: 0.8400
# Epoch 123/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1679 - accuracy: 0.8800
# Epoch 124/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2081 - accuracy: 0.8400
# Epoch 125/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2122 - accuracy: 0.8400
# Epoch 126/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2014 - accuracy: 0.8400
# Epoch 127/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1955 - accuracy: 0.8800
# Epoch 128/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2014 - accuracy: 0.9200
# Epoch 129/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1917 - accuracy: 0.8400
# Epoch 130/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1713 - accuracy: 0.8800
# Epoch 131/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2164 - accuracy: 0.8800
# Epoch 132/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2191 - accuracy: 0.8400
# Epoch 133/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1711 - accuracy: 0.8800
# Epoch 134/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1570 - accuracy: 0.9200
# Epoch 135/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1789 - accuracy: 0.8400
# Epoch 136/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9600
# Epoch 137/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1675 - accuracy: 0.8800
# Epoch 138/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2178 - accuracy: 0.8000
# Epoch 139/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1349 - accuracy: 0.9600
# Epoch 140/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.9200
# Epoch 141/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1608 - accuracy: 0.9200
# Epoch 142/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1393 - accuracy: 0.9600
# Epoch 143/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1664 - accuracy: 0.9200
# Epoch 144/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.8800
# Epoch 145/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1813 - accuracy: 0.8800
# Epoch 146/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1697 - accuracy: 0.8800
# Epoch 147/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1638 - accuracy: 0.8800
# Epoch 148/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2208 - accuracy: 0.8400
# Epoch 149/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1890 - accuracy: 0.8800
# Epoch 150/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2380 - accuracy: 0.8400
# Epoch 151/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2451 - accuracy: 0.8000
# Epoch 152/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1504 - accuracy: 0.8800
# Epoch 153/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2114 - accuracy: 0.8400
# Epoch 154/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2089 - accuracy: 0.8400
# Epoch 155/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1514 - accuracy: 0.9200
# Epoch 156/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1883 - accuracy: 0.8800
# Epoch 157/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1523 - accuracy: 0.9600
# Epoch 158/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2563 - accuracy: 0.8400
# Epoch 159/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1827 - accuracy: 0.8800
# Epoch 160/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2056 - accuracy: 0.8800
# Epoch 161/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1804 - accuracy: 0.8400
# Epoch 162/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1890 - accuracy: 0.8400
# Epoch 163/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1813 - accuracy: 0.8400
# Epoch 164/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1240 - accuracy: 0.9600
# Epoch 165/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1840 - accuracy: 0.8400
# Epoch 166/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1421 - accuracy: 0.9600
# Epoch 167/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1955 - accuracy: 0.8400
# Epoch 168/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2039 - accuracy: 0.8400
# Epoch 169/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1965 - accuracy: 0.8400
# Epoch 170/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1709 - accuracy: 0.8800
# Epoch 171/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2166 - accuracy: 0.8800
# Epoch 172/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1552 - accuracy: 0.9200
# Epoch 173/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1620 - accuracy: 0.8800
# Epoch 174/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1379 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1892 - accuracy: 0.8400
# Epoch 176/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2125 - accuracy: 0.8000
# Epoch 177/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1482 - accuracy: 0.9200
# Epoch 178/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1500 - accuracy: 0.9200
# Epoch 179/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1861 - accuracy: 0.8800
# Epoch 180/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1988 - accuracy: 0.8400
# Epoch 181/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1718 - accuracy: 0.8800
# Epoch 182/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2114 - accuracy: 0.8000
# Epoch 183/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.8000
# Epoch 184/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1513 - accuracy: 0.9200
# Epoch 185/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1945 - accuracy: 0.8800
# Epoch 186/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1850 - accuracy: 0.8400
# Epoch 187/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1931 - accuracy: 0.8400
# Epoch 188/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2122 - accuracy: 0.8400
# Epoch 189/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2420 - accuracy: 0.7600
# Epoch 190/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1739 - accuracy: 0.8800
# Epoch 191/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.8800
# Epoch 192/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1701 - accuracy: 0.8800
# Epoch 193/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1534 - accuracy: 0.9200
# Epoch 194/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1574 - accuracy: 0.8800
# Epoch 195/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1748 - accuracy: 0.9200
# Epoch 196/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1730 - accuracy: 0.9200
# Epoch 197/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.8800
# Epoch 198/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1822 - accuracy: 0.8800
# Epoch 199/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1976 - accuracy: 0.8800
# Epoch 200/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1756 - accuracy: 0.9200

# %%
def ourText(text):
    newtkns = nltk.word_tokenize(text)
    newtkns = [lm.lemmatize(word) for word in newtkns]
    return newtkns


def wordBag(text, vocab):
    newtkns = ourText(text)
    bagOwords = [0] * len(vocab)
    for w in newtkns:
        for idx, word in enumerate(vocab):
            if word == w:
                bagOwords[idx] = 1
    return num.array(bagOwords)


def Pclass(text, vocab, labels):
    bagOwords = wordBag(text, vocab)
    ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
    newThresh = 0.2
    yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

    yp.sort(key=lambda x: x[1], reverse=True)
    newList = []
    for r in yp:
        newList.append(labels[r[0]])
    return newList


def getRes(firstlist, fJson):
    tag = firstlist[0]
    listOfIntents = fJson["intents"]
    for i in listOfIntents:
        if i["tag"] == tag:
            ourResult = random.choice(i["responses"])
            break
    return ourResult

# %%
# while True:
#     newMessage = input("")
#     intents = Pclass(newMessage, newWords, ourClasses)
#     ourResult = getRes(intents, data)
#     print(ourResult)

# %%
import pandas as pd

df = pd.read_excel("Schedule_Cleaned.xlsm")
df
# Out:
#         Date        Day Coach/Associate    Name Week Cohort           Task  \
# 0 2022-11-28     Monday           Coach     NaN  W12     C6  Final Project
# 1 2022-11-29    Tuesday           Coach     NaN  W12     C6  Final Project
# 2 2022-11-30  Wednesday           Coach     NaN  W12     C6  Academy + (1)
# 3 2022-12-01   Thursday           Coach     NaN  W12     C6  Academy + (1)
# 4 2022-12-02     Friday           Coach     NaN  W12     C6  Academy + (1)
# 5 2022-11-28     Monday       Associate  Nathan  W12     C6  Final Project
# 6 2022-11-29    Tuesday       Associate  Nathan  W12     C6  Final Project
# 7 2022-11-30  Wednesday       Associate  Nathan  W12     C6  Academy + (1)
# 8 2022-12-01   Thursday       Associate  Nathan  W12     C6  Academy + (1)
# 9 2022-12-02     Friday       Associate  Nathan  W12     C6  Academy + (1)
#
#                                   AM               PM    EOD
# 0          Waseem Career Talks 11-12              NaN    NaN
# 1                                NaN              NaN    NaN
# 2                                NaN              NaN    NaN
# 3                                NaN              NaN    NaN
# 4                                NaN              NaN    NaN
# 5                                Dev          Project  Admin
# 6                            Project          Project  Admin
# 7  Set on Academy Portfolio Building              Dev  Admin
# 8                                Dev              Dev  Admin
# 9                    C7 Presentation  C7 Presentation  Admin

# %%
intents = Pclass("What are doing tomorrow?", newWords, ourClasses)
intents
# Out:
# 1/1 [==============================] - 0s 47ms/step
# ['tomorrow']

# %%
if intents[0] == 'tomorrow':
    display(df[["Coach/Associate", "Name"]])

if intents[0] == "tomorrow":
    # date2 = datetime.date.today() + datetime.timedelta(days=1)
    # print(date2)
    date1 = datetime.date.today() - datetime.timedelta(days=11)
    Task1 = df.query('Date == @date1')['Task'].to_list()
    CoachAssociate = df.query('Date == @date1')['Coach/Associate'].to_list()
    Name1 = df.query('Date == @date1')['Name'].to_list()
    while True:
        Name =  input("Please input the Coach or Associates Coachs Name.")
        if Name not in ('Nathan','NaN'):
            print("Enter either this names exactly, Nathan or NaN")
        
        else:
            if Name == "Nathan":
                print("Tomorrow, {}, {}, will be teaching {}.".format(CoachAssociate[1],Name1[1],Task1[1]))
                print(CoachAssociate)
                print(Task1[1])
        
            if Name == "NaN":
                print("Tomorrow, {}, {}, will be teaching {}.".format(CoachAssociate[0],Name1[0],Task1[0]))
            break

    #TODO what is the poandas stuff i need to answer the question 
#     pass
# if intents =="another task":
#     pass
#     # TODO more pandas stuff
# Out:
#   Coach/Associate    Name
# 0           Coach     NaN
# 1           Coach     NaN
# 2           Coach     NaN
# 3           Coach     NaN
# 4           Coach     NaN
# 5       Associate  Nathan
# 6       Associate  Nathan
# 7       Associate  Nathan
# 8       Associate  Nathan
# 9       Associate  Nathan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[139], line 18
#      16 else:
#      17     if Name == "Nathan":
# ---> 18         print("Tomorrow, {}, {}, will be teaching {}.".format(CoachAssociate[1],Name1[1],Task1[1]))
#      19         print(CoachAssociate)
#      20         print(Task1[1])
#
# IndexError: list index out of range

# %%
intents2 = Pclass("What are we doing on monday?", newWords, ourClasses)
intents2
# Out:
# 1/1 [==============================] - 0s 34ms/step
# ['monday']

# %%
if intents2[0] == 'monday':
    display(df[["Coach/Associate", "Name"]])

if intents2[0] == "monday":
    # date2 = datetime.date.today() + datetime.timedelta(days=1)
    # print(date2)
    date2 = datetime.date.today() + datetime.timedelta(days=-datetime.date.today().weekday(), weeks=1)-datetime.timedelta(days=21)
    print(date2)
    Task1 = df.query('Date == @date2')['Task'].to_list()
    CoachAssociate = df.query('Date == @date2')['Coach/Associate'].to_list()
    Name1 = df.query('Date == @date2')['Name'].to_list()
    am1 =  df.query('Date == @date2')['AM'].to_list()
    pm1 =  df.query('Date == @date2')['PM'].to_list()
    eod = df.query('Date == @date2')['EOD'].to_list()
    while True:
        Name =  input("Please input the Coach or Associates Coachs Name.")
        if Name not in ('Nathan','NaN'):
            print("Enter either this names exactly, Nathan or NaN")
        
        else:
            if Name == "Nathan":
                print("On Monday {}, {}, {}, will be teaching {} in the morning, {} in the afternoon and {} at the end of the day.".format(date2,CoachAssociate[1],Name1[1],am1[1],pm1[1],eod[1]))
                print(CoachAssociate)
                print(Task1[1])
        
            if Name == "NaN":
                print("Tomorrow, {}, {}, will be teaching {}.".format(CoachAssociate[0],Name1[0],Task1[0]))
            break

    #TODO what is the poandas stuff i need to answer the question 
#     pass
# if intents =="another task":
#     pass
#     # TODO more pandas stuff
# Out:
#   Coach/Associate    Name
# 0           Coach     NaN
# 1           Coach     NaN
# 2           Coach     NaN
# 3           Coach     NaN
# 4           Coach     NaN
# 5       Associate  Nathan
# 6       Associate  Nathan
# 7       Associate  Nathan
# 8       Associate  Nathan
# 9       Associate  Nathan
# 2022-11-28
# On Monday 2022-11-28, Associate, Nathan, will be teaching Dev in the morning, Project in the afternoon and Admin at the end of the day.
# ['Coach', 'Associate']
# Final Project
