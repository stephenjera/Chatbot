# %% [markdown]
# ### Helpful links
#
# * Code example: https://www.section.io/engineering-education/creating-chatbot-using-natural-language-processing-in-python/
#
# * Another code example: https://towardsdatascience.com/a-simple-chatbot-in-python-with-deep-learning-3e8669997758

# %% [markdown]
# ### Step one: Importing libraries

# %%
import json
import string
import random
import nltk
import datetime

nltk.download("omw-1.4")
import numpy as num
from nltk.stem import WordNetLemmatizer  # It has the ability to lemmatize.
import tensorflow as tensorF  # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")  # required package for tokenization
nltk.download("wordnet")  # word database
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\OlatoyosiOlamideBaba\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\OlatoyosiOlamideBaba\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\OlatoyosiOlamideBaba\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Step two: Creating a JSON file

# %%
data = {
    "intents": [
        {
            "tag": "age",
            "patterns": ["how old are you?"],
            "responses": ["I am 2 years old and my birthday was yesterday"],
        },
        {
            "tag": "greeting",
            "patterns": ["Hi", "Hello", "Hey"],
            "responses": ["Hi there", "Hello", "Hi :)"],
        },
        {
            "tag": "goodbye",
            "patterns": ["bye", "later"],
            "responses": ["Bye", "take care"],
        },
        {
            "tag": "name",
            "patterns": ["what's your name?", "who are you?"],
            "responses": [
                "I have no name yet," "You can give me one, and I will appreciate it"
            ],
        },
        {
            "tag": "coach",
            "patterns": ["Who is our data coach?", "Who is our Associate coach"],
            "responses": ["Data Coach, Associate coach"]
        },
        {
            "tag": "task",
            "patterns": ["What is my task?", "show me a task"],
            "responses": ["Data Coach, Associate coach"]
        },
        {
            "tag": "tomorrow",
            "patterns": ["What is my task tomorrow?", "show me a task next day", "What are we covering in class tomorrow?","tomorrow",],
            "responses": ["Data Coach, Associate coach"]
        },
         {
            "tag": "schedule",
            "patterns": ["What is my task tomorrow?", "show me a task next day", "What are we covering in class tomorrow?"],
            "responses": ["Data Coach, Associate coach"]
        },
        {
            "tag": "monday",
            "patterns": ["what am i doing on monday?","What is on monday","Tasks I need to complete on monday","Tasks for monday","Schedule for monday","Upcoming monday tasks"],
            "responses": ["Data Coach, Associate coach"]
        },
        
    ]
}

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation="softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss="categorical_crossentropy", optimizer=md, metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Neural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 128)               5504
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 9)                 585
#
# =================================================================
# Total params: 14,345
# Trainable params: 14,345
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 527ms/step - loss: 2.2798 - accuracy: 0.0800
# Epoch 2/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1210 - accuracy: 0.2400
# Epoch 3/200
# 1/1 [==============================] - 0s 17ms/step - loss: 1.9597 - accuracy: 0.3200
# Epoch 4/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8463 - accuracy: 0.3600
# Epoch 5/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8470 - accuracy: 0.2800
# Epoch 6/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6444 - accuracy: 0.3600
# Epoch 7/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5799 - accuracy: 0.3600
# Epoch 8/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3874 - accuracy: 0.4800
# Epoch 9/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3356 - accuracy: 0.5600
# Epoch 10/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0849 - accuracy: 0.6800
# Epoch 11/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1300 - accuracy: 0.6800
# Epoch 12/200
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0391 - accuracy: 0.6800
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9854 - accuracy: 0.6800
# Epoch 14/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8540 - accuracy: 0.7600
# Epoch 15/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8070 - accuracy: 0.8000
# Epoch 16/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6666 - accuracy: 0.8400
# Epoch 17/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6449 - accuracy: 0.7600
# Epoch 18/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6428 - accuracy: 0.7600
# Epoch 19/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5638 - accuracy: 0.8800
# Epoch 20/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5793 - accuracy: 0.7600
# Epoch 21/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4374 - accuracy: 0.8400
# Epoch 22/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3510 - accuracy: 0.8400
# Epoch 23/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5030 - accuracy: 0.7600
# Epoch 24/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3214 - accuracy: 0.9200
# Epoch 25/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3706 - accuracy: 0.8400
# Epoch 26/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3460 - accuracy: 0.8400
# Epoch 27/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4525 - accuracy: 0.7600
# Epoch 28/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4868 - accuracy: 0.8000
# Epoch 29/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3018 - accuracy: 0.8800
# Epoch 30/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2626 - accuracy: 0.9200
# Epoch 31/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2641 - accuracy: 0.8800
# Epoch 32/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5448 - accuracy: 0.7200
# Epoch 33/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2866 - accuracy: 0.8800
# Epoch 34/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2053 - accuracy: 0.8800
# Epoch 35/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4665 - accuracy: 0.7600
# Epoch 36/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3484 - accuracy: 0.8400
# Epoch 37/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2925 - accuracy: 0.8800
# Epoch 38/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2023 - accuracy: 0.9200
# Epoch 39/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2096 - accuracy: 0.8800
# Epoch 40/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2311 - accuracy: 0.9200
# Epoch 41/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2716 - accuracy: 0.8400
# Epoch 42/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3019 - accuracy: 0.8000
# Epoch 43/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3144 - accuracy: 0.8400
# Epoch 44/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2785 - accuracy: 0.8800
# Epoch 45/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2152 - accuracy: 0.8800
# Epoch 46/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.8800
# Epoch 47/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2358 - accuracy: 0.8800
# Epoch 48/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1784 - accuracy: 0.9200
# Epoch 49/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1875 - accuracy: 0.8800
# Epoch 50/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2035 - accuracy: 0.8400
# Epoch 51/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1739 - accuracy: 0.9600
# Epoch 52/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3497 - accuracy: 0.8000
# Epoch 53/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2866 - accuracy: 0.8000
# Epoch 54/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2104 - accuracy: 0.9200
# Epoch 55/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2401 - accuracy: 0.8800
# Epoch 56/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2402 - accuracy: 0.8400
# Epoch 57/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2328 - accuracy: 0.8400
# Epoch 58/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2180 - accuracy: 0.8400
# Epoch 59/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1547 - accuracy: 0.9600
# Epoch 60/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.8800
# Epoch 61/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2690 - accuracy: 0.8400
# Epoch 62/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1895 - accuracy: 0.9600
# Epoch 63/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2310 - accuracy: 0.8400
# Epoch 64/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1898 - accuracy: 0.9200
# Epoch 65/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1994 - accuracy: 0.8400
# Epoch 66/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2889 - accuracy: 0.7600
# Epoch 67/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2409 - accuracy: 0.8400
# Epoch 68/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2549 - accuracy: 0.8800
# Epoch 69/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1602 - accuracy: 0.9200
# Epoch 70/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2621 - accuracy: 0.8800
# Epoch 71/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2227 - accuracy: 0.8800
# Epoch 72/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1862 - accuracy: 0.9200
# Epoch 73/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1623 - accuracy: 0.9200
# Epoch 74/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2266 - accuracy: 0.8400
# Epoch 75/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2294 - accuracy: 0.8400
# Epoch 76/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2375 - accuracy: 0.8400
# Epoch 77/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2184 - accuracy: 0.8400
# Epoch 78/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.8400
# Epoch 79/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1859 - accuracy: 0.8800
# Epoch 80/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1854 - accuracy: 0.8400
# Epoch 81/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1744 - accuracy: 0.8400
# Epoch 82/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1851 - accuracy: 0.8000
# Epoch 83/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1903 - accuracy: 0.8800
# Epoch 84/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1672 - accuracy: 0.9600
# Epoch 85/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1735 - accuracy: 0.9600
# Epoch 86/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2117 - accuracy: 0.8800
# Epoch 87/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2377 - accuracy: 0.8800
# Epoch 88/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.8800
# Epoch 89/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2028 - accuracy: 0.8400
# Epoch 90/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1788 - accuracy: 0.9200
# Epoch 91/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1988 - accuracy: 0.8800
# Epoch 92/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1826 - accuracy: 0.8000
# Epoch 93/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1534 - accuracy: 0.9200
# Epoch 94/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1595 - accuracy: 0.9200
# Epoch 95/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1818 - accuracy: 0.9200
# Epoch 96/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2089 - accuracy: 0.8000
# Epoch 97/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1930 - accuracy: 0.9200
# Epoch 98/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2060 - accuracy: 0.7600
# Epoch 99/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1529 - accuracy: 0.9200
# Epoch 100/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2493 - accuracy: 0.8000
# Epoch 101/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1841 - accuracy: 0.8800
# Epoch 102/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1895 - accuracy: 0.9200
# Epoch 103/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1703 - accuracy: 0.9200
# Epoch 104/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2244 - accuracy: 0.8800
# Epoch 105/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1437 - accuracy: 0.9600
# Epoch 106/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1974 - accuracy: 0.8400
# Epoch 107/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1779 - accuracy: 0.8400
# Epoch 108/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1826 - accuracy: 0.8800
# Epoch 109/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1740 - accuracy: 0.9200
# Epoch 110/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1593 - accuracy: 0.8800
# Epoch 111/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1819 - accuracy: 0.8400
# Epoch 112/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.9200
# Epoch 113/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1459 - accuracy: 0.9200
# Epoch 114/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2126 - accuracy: 0.8400
# Epoch 115/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2307 - accuracy: 0.8000
# Epoch 116/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2274 - accuracy: 0.8400
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1421 - accuracy: 0.9200
# Epoch 118/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1958 - accuracy: 0.8800
# Epoch 119/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2017 - accuracy: 0.8000
# Epoch 120/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1793 - accuracy: 0.9200
# Epoch 121/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1807 - accuracy: 0.8000
# Epoch 122/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1865 - accuracy: 0.8000
# Epoch 123/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1559 - accuracy: 0.9600
# Epoch 124/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2012 - accuracy: 0.8800
# Epoch 125/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1838 - accuracy: 0.8800
# Epoch 126/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1566 - accuracy: 0.9600
# Epoch 127/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2006 - accuracy: 0.8400
# Epoch 128/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1349 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1545 - accuracy: 0.8800
# Epoch 130/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1545 - accuracy: 0.8800
# Epoch 131/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1401 - accuracy: 0.9200
# Epoch 132/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2166 - accuracy: 0.8800
# Epoch 133/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2012 - accuracy: 0.8400
# Epoch 134/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1794 - accuracy: 0.8800
# Epoch 135/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1818 - accuracy: 0.8400
# Epoch 136/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3592 - accuracy: 0.7600
# Epoch 137/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1701 - accuracy: 0.8800
# Epoch 138/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2130 - accuracy: 0.8400
# Epoch 139/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1587 - accuracy: 0.9200
# Epoch 140/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1917 - accuracy: 0.8800
# Epoch 141/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2452 - accuracy: 0.8800
# Epoch 142/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1524 - accuracy: 0.9200
# Epoch 143/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1702 - accuracy: 0.9200
# Epoch 144/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2046 - accuracy: 0.8400
# Epoch 145/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1859 - accuracy: 0.8800
# Epoch 146/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1482 - accuracy: 0.9600
# Epoch 147/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2021 - accuracy: 0.9200
# Epoch 148/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1647 - accuracy: 0.8800
# Epoch 149/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1772 - accuracy: 0.8400
# Epoch 150/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1467 - accuracy: 0.9600
# Epoch 151/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1730 - accuracy: 0.9600
# Epoch 152/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1354 - accuracy: 0.9600
# Epoch 153/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1741 - accuracy: 0.8400
# Epoch 154/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2188 - accuracy: 0.8000
# Epoch 155/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1691 - accuracy: 0.8800
# Epoch 156/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1831 - accuracy: 0.8800
# Epoch 157/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2365 - accuracy: 0.8800
# Epoch 158/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1627 - accuracy: 0.8800
# Epoch 159/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1834 - accuracy: 0.9200
# Epoch 160/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2174 - accuracy: 0.8400
# Epoch 161/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2122 - accuracy: 0.8800
# Epoch 162/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1743 - accuracy: 0.8400
# Epoch 163/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.8400
# Epoch 164/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1743 - accuracy: 0.8400
# Epoch 165/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2168 - accuracy: 0.8800
# Epoch 166/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1855 - accuracy: 0.8800
# Epoch 167/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1842 - accuracy: 0.8800
# Epoch 168/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1873 - accuracy: 0.8800
# Epoch 169/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1672 - accuracy: 0.8800
# Epoch 170/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1854 - accuracy: 0.8800
# Epoch 171/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2121 - accuracy: 0.8400
# Epoch 172/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1896 - accuracy: 0.8400
# Epoch 173/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2092 - accuracy: 0.8800
# Epoch 174/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1632 - accuracy: 0.9600
# Epoch 175/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1792 - accuracy: 0.8800
# Epoch 176/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1947 - accuracy: 0.8800
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1744 - accuracy: 0.8800
# Epoch 178/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1734 - accuracy: 0.9200
# Epoch 179/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1645 - accuracy: 0.9600
# Epoch 180/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1823 - accuracy: 0.8800
# Epoch 181/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1911 - accuracy: 0.8400
# Epoch 182/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2029 - accuracy: 0.8400
# Epoch 183/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1946 - accuracy: 0.8400
# Epoch 184/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1752 - accuracy: 0.8800
# Epoch 185/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1733 - accuracy: 0.8800
# Epoch 186/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1527 - accuracy: 0.9200
# Epoch 187/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1822 - accuracy: 0.8800
# Epoch 188/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1580 - accuracy: 0.9600
# Epoch 189/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2312 - accuracy: 0.8800
# Epoch 190/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1560 - accuracy: 0.8800
# Epoch 191/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2167 - accuracy: 0.8400
# Epoch 192/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1900 - accuracy: 0.8800
# Epoch 193/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1656 - accuracy: 0.9600
# Epoch 194/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1811 - accuracy: 0.8400
# Epoch 195/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1273 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2188 - accuracy: 0.8000
# Epoch 197/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1478 - accuracy: 0.9600
# Epoch 198/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1996 - accuracy: 0.8800
# Epoch 199/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1838 - accuracy: 0.8800
# Epoch 200/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1800 - accuracy: 0.8400

# %%
def ourText(text):
    newtkns = nltk.word_tokenize(text)
    newtkns = [lm.lemmatize(word) for word in newtkns]
    return newtkns


def wordBag(text, vocab):
    newtkns = ourText(text)
    bagOwords = [0] * len(vocab)
    for w in newtkns:
        for idx, word in enumerate(vocab):
            if word == w:
                bagOwords[idx] = 1
    return num.array(bagOwords)


def Pclass(text, vocab, labels):
    bagOwords = wordBag(text, vocab)
    ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
    newThresh = 0.2
    yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

    yp.sort(key=lambda x: x[1], reverse=True)
    newList = []
    for r in yp:
        newList.append(labels[r[0]])
    return newList


def getRes(firstlist, fJson):
    tag = firstlist[0]
    listOfIntents = fJson["intents"]
    for i in listOfIntents:
        if i["tag"] == tag:
            ourResult = random.choice(i["responses"])
            break
    return ourResult

def get_res(intents, df):
    if intents[0] == 'tomorrow':
        return display(df[["Coach/Associate", "Name"]])

# %%
import pandas as pd

df = pd.read_excel("Schedule_Cleaned.xlsm")
df
# Out:
#         Date        Day Coach/Associate    Name Week Cohort           Task  \
# 0 2022-11-28     Monday           Coach     NaN  W12     C6  Final Project
# 1 2022-11-29    Tuesday           Coach     NaN  W12     C6  Final Project
# 2 2022-11-30  Wednesday           Coach     NaN  W12     C6  Academy + (1)
# 3 2022-12-01   Thursday           Coach     NaN  W12     C6  Academy + (1)
# 4 2022-12-02     Friday           Coach     NaN  W12     C6  Academy + (1)
# 5 2022-11-28     Monday       Associate  Nathan  W12     C6  Final Project
# 6 2022-11-29    Tuesday       Associate  Nathan  W12     C6  Final Project
# 7 2022-11-30  Wednesday       Associate  Nathan  W12     C6  Academy + (1)
# 8 2022-12-01   Thursday       Associate  Nathan  W12     C6  Academy + (1)
# 9 2022-12-02     Friday       Associate  Nathan  W12     C6  Academy + (1)
#
#                                   AM               PM    EOD
# 0          Waseem Career Talks 11-12              NaN    NaN
# 1                                NaN              NaN    NaN
# 2                                NaN              NaN    NaN
# 3                                NaN              NaN    NaN
# 4                                NaN              NaN    NaN
# 5                                Dev          Project  Admin
# 6                            Project          Project  Admin
# 7  Set on Academy Portfolio Building              Dev  Admin
# 8                                Dev              Dev  Admin
# 9                    C7 Presentation  C7 Presentation  Admin

# %%
intents = Pclass("What are doing tomorrow?", newWords, ourClasses)
intents
# Out:
# 1/1 [==============================] - 0s 60ms/step
# ['tomorrow']

# %%
while True:
    newMessage = input("")
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = get_res(intents, df=df)
    print(ourResult)

# %%
if intents[0] == 'tomorrow':
    display(df[["Coach/Associate", "Name"]])

if intents[0] == "tomorrow":
    # date2 = datetime.date.today() + datetime.timedelta(days=1)
    # print(date2)
    date1 = datetime.date.today() - datetime.timedelta(days=11)
    Task1 = df.query('Date == @date1')['Task'].to_list()
    CoachAssociate = df.query('Date == @date1')['Coach/Associate'].to_list()
    Name1 = df.query('Date == @date1')['Name'].to_list()
    while True:
        Name =  input("Please input the Coach or Associates Coachs Name.")
        if Name not in ('Nathan','NaN'):
            print("Enter either this names exactly, Nathan or NaN")
        
        else:
            if Name == "Nathan":
                print("Tomorrow, {}, {}, will be teaching {}.".format(CoachAssociate[1],Name1[1],Task1[1]))
                print(CoachAssociate)
                print(Task1[1])
        
            if Name == "NaN":
                print("Tomorrow, {}, {}, will be teaching {}.".format(CoachAssociate[0],Name1[0],Task1[0]))
            break

    #TODO what is the poandas stuff i need to answer the question 
#     pass
# if intents =="another task":
#     pass
#     # TODO more pandas stuff
# Out:
#   Coach/Associate    Name
# 0           Coach     NaN
# 1           Coach     NaN
# 2           Coach     NaN
# 3           Coach     NaN
# 4           Coach     NaN
# 5       Associate  Nathan
# 6       Associate  Nathan
# 7       Associate  Nathan
# 8       Associate  Nathan
# 9       Associate  Nathan

# %%
intents2 = Pclass("What are we doing on monday?", newWords, ourClasses)
intents2
# Out:
# 1/1 [==============================] - 0s 34ms/step
# ['monday']

# %%
if intents2[0] == 'monday':
    display(df[["Coach/Associate", "Name"]])

if intents2[0] == "monday":
    # date2 = datetime.date.today() + datetime.timedelta(days=1)
    # print(date2)
    date2 = datetime.date.today() + datetime.timedelta(days=-datetime.date.today().weekday(), weeks=1)-datetime.timedelta(days=21)
    print(date2)
    Task1 = df.query('Date == @date2')['Task'].to_list()
    CoachAssociate = df.query('Date == @date2')['Coach/Associate'].to_list()
    Name1 = df.query('Date == @date2')['Name'].to_list()
    am1 =  df.query('Date == @date2')['AM'].to_list()
    pm1 =  df.query('Date == @date2')['PM'].to_list()
    eod = df.query('Date == @date2')['EOD'].to_list()
    while True:
        Name =  input("Please input the Coach or Associates Coachs Name.")
        if Name not in ('Nathan','NaN'):
            print("Enter either this names exactly, Nathan or NaN")
        
        else:
            if Name == "Nathan":
                print("On Monday {}, {}, {}, will be teaching {} in the morning, {} in the afternoon and {} at the end of the day.".format(date2,CoachAssociate[1],Name1[1],am1[1],pm1[1],eod[1]))
                print(CoachAssociate)
                print(Task1[1])
        
            if Name == "NaN":
                print("Tomorrow, {}, {}, will be teaching {}.".format(CoachAssociate[0],Name1[0],Task1[0]))
            break

    #TODO what is the poandas stuff i need to answer the question 
#     pass
# if intents =="another task":
#     pass
#     # TODO more pandas stuff
# Out:
#   Coach/Associate    Name
# 0           Coach     NaN
# 1           Coach     NaN
# 2           Coach     NaN
# 3           Coach     NaN
# 4           Coach     NaN
# 5       Associate  Nathan
# 6       Associate  Nathan
# 7       Associate  Nathan
# 8       Associate  Nathan
# 9       Associate  Nathan
# 2022-11-28
# On Monday 2022-11-28, Associate, Nathan, will be teaching Dev in the morning, Project in the afternoon and Admin at the end of the day.
# ['Coach', 'Associate']
# Final Project
